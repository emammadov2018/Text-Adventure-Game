# %%
### Student name: Elnur Mammadov
#Assignment: Text Adventure Game based on movie called Squid Game
#Date: 10.23.2021

import random
import time
from sys import exit
# This is the summary of the game based on TV show
def summary():
    print("""
Squid Game is about a mysterious and deadly survival game for people in 
desperate need of the prize money on offer. People who are all in debt are 
invited to play in a games style challenge tournament to win a huge prize 
fund and solve their money issues. All they have to do is compete in, and 
win, a bunch of challenges based on old kid games. However, it soon becomes
a harsh game of survival, when “losers” are brutally killed """)
    input(prompt = "<Press enter to continue>\n")
    game_0()

time.sleep(3) # 3 second duration between code
#Asking player whether they want to play the game or not
def game_0():
    print("Lets start our game!!!!!!!!!!!!")
    print("""
I feel that you also need money. And I want to solve your problem. 
If you play a game with me, you can easily earn this money without 
losing anything. There is only one condition of the game, if you win 
you will get $ 1000, if I win I will slap your face """)
    print("Would you like to play a game??")
    print('<Press 1 for "Yes" and 2 for "No"\n')
    answer = input(prompt = "> ")
    if '1' or "Yes" in answer:
        print("Perfect")
        input(prompt ='<Press any key to continue>\n')
        game_1()       
    elif "2" or "No" in answer :
        print("I am sorry for hearing that you dont want to play game with me")
        input(prompt = '<Press any key to continue>\n')
        fail_2()
    else:
        print("Invalid entry. Please try again.\n")
        input(prompt ='<Press any key to continue>\n')
        game_0()

#This is the first game for selecting to main competition                
def game_1():
    print("""
You will compete with 45 players in this competition and only 1 can 
survive from this competition and get 45 million dollars""")
    print( 
"""
First game is called "Ddajki", it is a paper game and you hit the opponent's card and try to flip it
Now you have to choose the best tactic to win your opponent.\n
Choose the best tactic to win this game?
1) Hit the paper slowly no matter where you hit
2) Hit the center of the paper
3) Hit the corners of the paper
        
""")
#asking players to make a choice.     
    answer_2 = input(prompt = "> ")
        
    # Start to conditional statements
    if '3' or "Corners" in answer_2:
        print("That's correct. You flipped the opponent's paper and won 1000$. Congratulations")
        
        print("You are selected!!!! Now you can participate our competition")
        game_2()
    #There is loser for this game that is why I gave infinite chances to players to choose correct answer.        
    elif '2'or "Center" in answer_2:
        print("That's incorrect! Opponent slapped you face. Try other tactic")
        input(prompt = '<Press any key to continue>\n')
        game_1()
    # The main reason to give a chance to player is to see their ambition to join the main competition         
    elif answer_2 =='1':
        print("That's incorrect! Opponent slapped you face. Try other tactic")
        input(prompt = '<Press any key to continue>\n')
        game_1()
    else:
        print("Invalid entry. Please try again.\n") #If players insert letters or other number, they can try again
        input(prompt = '<Press any key to continue>\n')
        game_1()
#This is the first game from main competition.
def game_2():

    print("""
You're in game_2! Which is called Red light and Green light. When you 
see red light you have to stop, when you see green light,you have to 
run and reach finish line as soon as possible\n""")
    input(prompt = '<Press any key to continue>\n')  #asking players to make a choice. 
    print( 
"""
Green Light!!!!!!
1) Run until you hear "Red light"
2) Do not move anywhere and wait in place
3) Hide behind other players
        
""")
    
    answer = input(prompt = "> ")   #asking players to make a choice. 
    
    if answer == '1':
        print("That is the right choice, you won a ticket to the 3rd game" )
        game_3()

    elif answer == '2':
        fail()
    
    elif answer == "3":
        fail()
    
    else:
        print("Invalid entry. Please try again.\n")  #If players insert letters or other number, they can try again
        game_2()


def game_3():
    print("Good to see you in next game, FYI 32 players were eliminated")
    print("You're in game_3!\n")
    print("This game is called Sugar Honeycombs")
    time.sleep(3)
    print("Before starting this game, you have to choose one number")

#Symbols    
# 1 = triangle
# 2 = circle
# 3 = star 
# 4 = umbrella
    number = random.randint(1,4)

    while True:
        answer = input( prompt = '\n What is your guess (1-4)?\n> ')

        answer = int(answer) #Changing answer to integer

        if answer == number:
            print("\nTriangle, This is the best symbol for this game")
            break

        elif answer != number:
            if answer>number:
                print(f"Umbrella. This is your symbol")
                break
            elif answer < number:
                print(f"Star. This is your symbol")
                break
        else:
            print("\n Something went wrong.")
            game_3()
    print("""
You're in game_3! Which is called "Sugar Honeycombs". 
Sugar honeycomb with one of four different shapes modelled into it: 
a circle, a triangle, a star or an umbrella. Armed with nothing but 
a needle, the players have to carve out the shapes without breaking their 
design – if the shape doesn’t come out whole, the player is killed""")
    input(prompt = '<Press any key to continue>\n')
    print( 
f"""
Which tactic you will use for carving out the shapes without breaking your symbol?
1) I will use only the needle 
2) I will lick the entire candy and then scratching out the shape with needle
3) I will try to break it down into smaller pieces
        
""")
    
    answer_3 = input(prompt = "> ")
    
    if answer_3 == '1':
        fail()

    elif answer_3 == '2':
        print("The right choice, you won a ticket to the 4rd game")
        game_4()
    elif answer_3 == "3":
        fail()
    else:
        print("Invalid entry. Please try again.\n")
        game_3()


def game_4():
    print("11 players were eliminated and last 2 players are going to fight for 45 million")
    print("""
You are in game_4. This game is called Marbles,
You have to pick some number of marbles in their fist and ask the 
opposite player to guess whether he/she has a number of marbles. 
If the guess is correct then the player who is playing has to return
those marbles to the opposite player, if guess is wrong then the 
opposite player has to give that the numbers of marbles to the 
player""")
    input(prompt = "<Press enter to continue>\n")
    number = random.randint(0,10)

    while True:
        answer_4 = input( prompt = '\n What is your guess (1-10)?\n> ')
        answer_4 = int(answer_4)
        if answer_4 == number:
            print(f"\nYou won",answer_4," marbles from your opponent!")
            win()

        elif answer_4 != number:
            if answer_4>number:
                print(f"\nYou won",answer_4," marbles from your opponent!") # creating more probability for player to win this game
                win()
            elif answer_4 < number:
                print(f"That is incorrect. You lost all your marbles")
                print("<Try again for guessing correct answer>\n") # No losing in this game, players need to guess correct number
    # setting a different error message for inner and outer loops
        else:
            print("\n Something went wrong.")
#This is the win function and only winner will see this function
def win():
    print("""
You have completed all games of "Squid Game"! Great job!
          """)
    print("""
You win 45 million dollar.Congratulations
""")
    print("""

██╗░░░██╗░█████╗░██╗░░░██╗  ░██╗░░░░░░░██╗██╗███╗░░██╗██╗██╗██╗
╚██╗░██╔╝██╔══██╗██║░░░██║  ░██║░░██╗░░██║██║████╗░██║██║██║██║
░╚████╔╝░██║░░██║██║░░░██║  ░╚██╗████╗██╔╝██║██╔██╗██║██║██║██║
░░╚██╔╝░░██║░░██║██║░░░██║  ░░████╔═████║░██║██║╚████║╚═╝╚═╝╚═╝
░░░██║░░░╚█████╔╝╚██████╔╝  ░░╚██╔╝░╚██╔╝░██║██║░╚███║██╗██╗██╗
░░░╚═╝░░░░╚════╝░░╚═════╝░  ░░░╚═╝░░░╚═╝░░╚═╝╚═╝░░╚══╝╚═╝╚═╝╚═╝

░█████╗░░█████╗░███╗░░██╗░██████╗░██████╗░░█████╗░████████╗██╗░░░██╗██╗░░░░░░█████╗░████████╗██╗░█████╗░███╗░░██╗░██████╗
██╔══██╗██╔══██╗████╗░██║██╔════╝░██╔══██╗██╔══██╗╚══██╔══╝██║░░░██║██║░░░░░██╔══██╗╚══██╔══╝██║██╔══██╗████╗░██║██╔════╝
██║░░╚═╝██║░░██║██╔██╗██║██║░░██╗░██████╔╝███████║░░░██║░░░██║░░░██║██║░░░░░███████║░░░██║░░░██║██║░░██║██╔██╗██║╚█████╗░
██║░░██╗██║░░██║██║╚████║██║░░╚██╗██╔══██╗██╔══██║░░░██║░░░██║░░░██║██║░░░░░██╔══██║░░░██║░░░██║██║░░██║██║╚████║░╚═══██╗
╚█████╔╝╚█████╔╝██║░╚███║╚██████╔╝██║░░██║██║░░██║░░░██║░░░╚██████╔╝███████╗██║░░██║░░░██║░░░██║╚█████╔╝██║░╚███║██████╔╝
░╚════╝░░╚════╝░╚═╝░░╚══╝░╚═════╝░╚═╝░░╚═╝╚═╝░░╚═╝░░░╚═╝░░░░╚═════╝░╚══════╝╚═╝░░╚═╝░░░╚═╝░░░╚═╝░╚════╝░╚═╝░░╚══╝╚═════╝░
""")
    input(prompt = "<Press enter to exit, you champion!>\n")
    exit(0) #Exit function for finishing game          
            
# Fail function for 
def fail():
    print("You've eliminated, the cost for losing is death.")
    time.sleep(2)
    print("""Would you like to play again??, <Press 1 for "Yes" and 2 for "No"\n""")
    answer = input(prompt = "> ")
    try:
        if answer == '1':
            print("Perfect")
            summary()       
        elif answer == '2':
            print("I am sorry for hearing that you dont want to play game with me")
            input(prompt = '<Press any key to exit>\n')
    except:
        print("Invalid entry. Please try again.\n")
        input(prompt = '<Press any key to continue>\n')
        fail()
#fail function for who does not want to play game either
def fail_2():
    print("""Would you like to play again??, <Press 1 for "Yes" and 2 for "No"\n""")
    answer = input(prompt = "> ")
    try:
        if answer == '1':
            print("Perfect")
            summary()       
        elif answer == '2':
            print("I am sorry for hearing that you dont want to play game with me")
            input(prompt = '<Press any key to exit>\n')
    except:
        print("Invalid entry. Please try again.\n")
        input(prompt = '<Press any key to continue>\n')
        fail()
        
summary()   #starting point
